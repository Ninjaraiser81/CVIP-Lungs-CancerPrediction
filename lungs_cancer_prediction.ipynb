# %% [markdown]
# # LIBRARIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import seaborn as sns

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # LOADING DATASETS

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data = pd.read_csv('/content/drive/MyDrive/survey lung cancer.csv')
data.head()
# Out:
#   GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0      M   69        1               2        2              1
# 1      M   74        2               1        1              1
# 2      F   59        1               1        1              2
# 3      M   63        2               2        2              1
# 4      F   63        1               2        1              1
#
#    CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  COUGHING  \
# 0                1         2         1         2                  2         2
# 1                2         2         2         1                  1         1
# 2                1         2         1         2                  1         2
# 3                1         1         1         1                  2         1
# 4                1         1         1         2                  1         2
#
#    SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN LUNG_CANCER
# ...

# %%
data.shape,data.size
# Out:
# ((309, 16), 4944)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309 entries, 0 to 308
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GENDER                 309 non-null    object
#  1   AGE                    309 non-null    int64
#  2   SMOKING                309 non-null    int64
#  3   YELLOW_FINGERS         309 non-null    int64
#  4   ANXIETY                309 non-null    int64
#  5   PEER_PRESSURE          309 non-null    int64
#  6   CHRONIC DISEASE        309 non-null    int64
#  7   FATIGUE                309 non-null    int64
#  8   ALLERGY                309 non-null    int64
#  9   WHEEZING               309 non-null    int64
#  10  ALCOHOL CONSUMING      309 non-null    int64
#  11  COUGHING               309 non-null    int64
#  12  SHORTNESS OF BREATH    309 non-null    int64
#  13  SWALLOWING DIFFICULTY  309 non-null    int64
#  14  CHEST PAIN             309 non-null    int64
# ...

# %% [markdown]
# # TESING AND TRAINIG

# %%
train = pd.read_csv('/content/drive/MyDrive/survey lung cancer.csv')
train.head()
# Out:
#   GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0      M   69        1               2        2              1
# 1      M   74        2               1        1              1
# 2      F   59        1               1        1              2
# 3      M   63        2               2        2              1
# 4      F   63        1               2        1              1
#
#    CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  COUGHING  \
# 0                1         2         1         2                  2         2
# 1                2         2         2         1                  1         1
# 2                1         2         1         2                  1         2
# 3                1         1         1         1                  2         1
# 4                1         1         1         2                  1         2
#
#    SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN LUNG_CANCER
# ...

# %%
test = pd.read_csv('/content/drive/MyDrive/survey lung cancer.csv')
test.head()
#plt.show()
# Out:
#   GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0      M   69        1               2        2              1
# 1      M   74        2               1        1              1
# 2      F   59        1               1        1              2
# 3      M   63        2               2        2              1
# 4      F   63        1               2        1              1
#
#    CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  COUGHING  \
# 0                1         2         1         2                  2         2
# 1                2         2         2         1                  1         1
# 2                1         2         1         2                  1         2
# 3                1         1         1         1                  2         1
# 4                1         1         1         2                  1         2
#
#    SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN LUNG_CANCER
# ...

# %%
train.isnull().sum()
print("Train Shape:",train.shape)
test.isnull().sum()
print("Test Shape:",test.shape)
# Out:
# Train Shape: (309, 16)
# Test Shape: (309, 16)

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309 entries, 0 to 308
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GENDER                 309 non-null    object
#  1   AGE                    309 non-null    int64
#  2   SMOKING                309 non-null    int64
#  3   YELLOW_FINGERS         309 non-null    int64
#  4   ANXIETY                309 non-null    int64
#  5   PEER_PRESSURE          309 non-null    int64
#  6   CHRONIC DISEASE        309 non-null    int64
#  7   FATIGUE                309 non-null    int64
#  8   ALLERGY                309 non-null    int64
#  9   WHEEZING               309 non-null    int64
#  10  ALCOHOL CONSUMING      309 non-null    int64
#  11  COUGHING               309 non-null    int64
#  12  SHORTNESS OF BREATH    309 non-null    int64
#  13  SWALLOWING DIFFICULTY  309 non-null    int64
#  14  CHEST PAIN             309 non-null    int64
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309 entries, 0 to 308
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GENDER                 309 non-null    object
#  1   AGE                    309 non-null    int64
#  2   SMOKING                309 non-null    int64
#  3   YELLOW_FINGERS         309 non-null    int64
#  4   ANXIETY                309 non-null    int64
#  5   PEER_PRESSURE          309 non-null    int64
#  6   CHRONIC DISEASE        309 non-null    int64
#  7   FATIGUE                309 non-null    int64
#  8   ALLERGY                309 non-null    int64
#  9   WHEEZING               309 non-null    int64
#  10  ALCOHOL CONSUMING      309 non-null    int64
#  11  COUGHING               309 non-null    int64
#  12  SHORTNESS OF BREATH    309 non-null    int64
#  13  SWALLOWING DIFFICULTY  309 non-null    int64
#  14  CHEST PAIN             309 non-null    int64
# ...

# %%
sns.pairplot(data=data,corner=True)
plt.show()

# %%
data.set_axis(['Sex','Age','Smoking','Yellow_fingers','Anxiety','Peer_Pressure','Chronic disease','Fatigue','Allergy','Wheezing','Alcohol consuming','Coughing','Shortness of breathe','Swallowing difficulty','Chest pain','Lung_cancer'],axis='columns',inplace=True)

# %%
data.head()
# Out:
#   Sex  Age  Smoking  Yellow_fingers  Anxiety  Peer_Pressure  Chronic disease  \
# 0   M   69        1               2        2              1                1
# 1   M   74        2               1        1              1                2
# 2   F   59        1               1        1              2                1
# 3   M   63        2               2        2              1                1
# 4   F   63        1               2        1              1                1
#
#    Fatigue  Allergy  Wheezing  Alcohol consuming  Coughing  \
# 0        2        1         2                  2         2
# 1        2        2         1                  1         1
# 2        2        1         2                  1         2
# 3        1        1         1                  2         1
# 4        1        1         2                  1         2
#
#    Shortness of breathe  Swallowing difficulty  Chest pain Lung_cancer
# 0                     2                      2           2         YES
# ...

# %%
plt.figure(figsize=(14,7))
sns.heatmap(data.corr(),annot=True,cmap='pink')
plt.plot()
# Out:
# []

# %%
mean=data.mean
mean()
# Out:
# Age                      62.673139
# Smoking                   1.563107
# Yellow_fingers            1.569579
# Anxiety                   1.498382
# Peer_Pressure             1.501618
# Chronic disease           1.504854
# Fatigue                   1.673139
# Allergy                   1.556634
# Wheezing                  1.556634
# Alcohol consuming         1.556634
# Coughing                  1.579288
# Shortness of breathe      1.640777
# Swallowing difficulty     1.469256
# Chest pain                1.556634
# dtype: float64

# %% [markdown]
# # EDA Testing

# %%
# %matplotlib inline
import plotly.express as px

# %%
fig=px.bar(data.head(100),x='Age',y='Smoking',template='ggplot2')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig=px.bar(data.head(),x='Lung_cancer',y='Age',template='ggplot2')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Age wise predicting the percentage of alcohol consuming

# %%
fig = px.pie(data, values='Alcohol consuming', names='Age')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.line(data, x="Sex", y="Age", color='Lung_cancer',markers=True,color_discrete_sequence=['White','orange'],template='plotly_dark')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df= data.copy()
df.head()
# Out:
#   Sex  Age  Smoking  Yellow_fingers  Anxiety  Peer_Pressure  Chronic disease  \
# 0   M   69        1               2        2              1                1
# 1   M   74        2               1        1              1                2
# 2   F   59        1               1        1              2                1
# 3   M   63        2               2        2              1                1
# 4   F   63        1               2        1              1                1
#
#    Fatigue  Allergy  Wheezing  Alcohol consuming  Coughing  \
# 0        2        1         2                  2         2
# 1        2        2         1                  1         1
# 2        2        1         2                  1         2
# 3        1        1         1                  2         1
# 4        1        1         2                  1         2
#
#    Shortness of breathe  Swallowing difficulty  Chest pain Lung_cancer
# 0                     2                      2           2         YES
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309 entries, 0 to 308
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Sex                    309 non-null    object
#  1   Age                    309 non-null    int64
#  2   Smoking                309 non-null    int64
#  3   Yellow_fingers         309 non-null    int64
#  4   Anxiety                309 non-null    int64
#  5   Peer_Pressure          309 non-null    int64
#  6   Chronic disease        309 non-null    int64
#  7   Fatigue                309 non-null    int64
#  8   Allergy                309 non-null    int64
#  9   Wheezing               309 non-null    int64
#  10  Alcohol consuming      309 non-null    int64
#  11  Coughing               309 non-null    int64
#  12  Shortness of breathe   309 non-null    int64
#  13  Swallowing difficulty  309 non-null    int64
#  14  Chest pain             309 non-null    int64
# ...

# %% [markdown]
# # Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['Sex']=le.fit_transform(df['Sex'])
df['Lung_cancer']=le.fit_transform(df['Lung_cancer'])
df
# Out:
#      Sex  Age  Smoking  Yellow_fingers  Anxiety  Peer_Pressure  \
# 0      1   69        0               2        1              1
# 1      1   74        1               1        0              1
# 2      0   59        0               1        0              2
# 3      1   63        1               2        1              1
# 4      0   63        0               2        0              1
# ..   ...  ...      ...             ...      ...            ...
# 304    0   56        0               1        0              2
# 305    1   70        1               1        0              1
# 306    1   58        1               1        0              1
# 307    1   67        1               1        1              1
# 308    1   62        0               1        0              2
#
#      Chronic disease  Fatigue  Allergy  Wheezing  Alcohol consuming  Coughing  \
# 0                  1        2        1         2                  2         2
# ...

# %%
from sklearn.preprocessing import LabelEncoder
l=LabelEncoder()
for i in df.columns:
    if df[i].dtype == 'object':
        df[i]=l.fit_transform(df[i])

# %%
X = df.drop('Lung_cancer',axis=1)
y = df['Lung_cancer']

from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(X, y, test_size=0.2, random_state=2)

# %% [markdown]
# # Random forest classifying

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error , r2_score
rf = RandomForestRegressor()
rf.fit(xtrain, ytrain)
# Out:
# RandomForestRegressor()

# %% [markdown]
# # Linear Regression
# applying classification algorithms

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error , r2_score

# %% [markdown]
# # Evaluating Training prediction

# %%
lr = LinearRegression()
lr.fit(xtrain, ytrain)

ytrain_pred = lr.predict(xtrain)

# evaluating the testing data

mse = mean_squared_error(ytrain, ytrain_pred)
rmse = (np.sqrt(mse))
r2 = r2_score(ytrain, ytrain_pred)

print("The model performance for training set")
print("--------------------------------------")
print('MSE is {}'.format(mse))
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")

#model training using regr
# Out:
# The model performance for training set
# --------------------------------------
# MSE is 0.06357796112262133
# RMSE is 0.2521467055557564
# R2 score is 0.40417391242242606

# %% [markdown]
# # Evaluating Testing prediction

# %%
ytest_pred = lr.predict(xtest)

mse = mean_squared_error(ytest, ytest_pred)
rmse = (np.sqrt(mean_squared_error(ytest, ytest_pred)))
r2 = r2_score(ytest, ytest_pred)

print("the model performance for training set")
print("--------------------------------------")
print('MSE is {}'.format(mse))
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")
# Out:
# the model performance for training set
# --------------------------------------
# MSE is 0.08558587668393218
# RMSE is 0.2925506395206344
# R2 score is 0.31028907762466396

# %% [markdown]
# # Decision Tree regression

# %%
from sklearn.tree import DecisionTreeRegressor
dtr=DecisionTreeRegressor(random_state=0)

# %%
dtr.fit(xtrain,ytrain)

#predicting the value

ytest_pred=dtr.predict(xtest)

#evaluating the model

from sklearn.metrics import r2_score,mean_squared_error
print("Results for Decision Tree Regression:\n1)Mean Square Error={}\n2)R-Square Score={}".format(mean_squared_error(ytest,ytest_pred),r2_score(ytest,ytest_pred)))
# Out:
# Results for Decision Tree Regression:
# 1)Mean Square Error=0.11290322580645161
# 2)R-Square Score=0.09014675052410914

# %% [markdown]
# # Final testing

# %%
np.random.seed(range(0,100))
print("Welcome to Lung cancer prediction!")
print("Enter the details")
print("----------------------------------")
Age=l.fit_transform([input('enter your Age:')])
Sex=int(input("enter the Sex:"))
Smoking=(float(input("enter your Smoking rate in % (it not enter 0):")))*10
Yellow_fingers=(float(input("enter your Yellow_fingers rate in % (it not enter 0):")))*10
Anxiety=(float(input("enter your Anxiety rate in % (it not enter 0):")))*10
Peer_Pressure=(float(input("enter your Peer_Pressure rate in % (it not enter 0):")))*10
Chronic=(float(input("enter your Chronic disease rate in % (it not enter 0):")))*10
Wheezing=(float(input("enter your Wheezing rate in % (it not enter 0):")))*10
Alcohol=(float(input("enter your Alcohol consuming rate in % (it not enter 0):")))*10
Fatigue=(float(input("enter your Fatigue rate in % (it not enter 0):")))*10
Coughing=(float(input("enter your Coughing rate in % (it not enter 0):")))*10
Shortness=(float(input("enter your Shortness of breathe rate in % (it not enter 0):")))*10
Swallowing=(float(input("enter your Swallowing difficulty rate in % (it not enter 0):")))*10
Chest=(float(input("enter your Chest pain rate in % (it not enter 0):")))*10
Lung_cancer=(float(input("enter your Lung_cancer rate in % (it not enter 0):")))*10

prediction=rf.predict([[Sex,Age,Smoking,Yellow_fingers,Anxiety,Peer_Pressure,Chronic,Wheezing,Alcohol,Fatigue,Coughing,Shortness,Swallowing,Chest,Lung_cancer]])*10
print("Your Lung cancer is prediction {}%".format(prediction))
print("have good day......!")
# Out:
# Welcome to Lung cancer prediction!
# Enter the details
# ----------------------------------
# enter your Age:69
# enter the Sex:1
# enter your Smoking rate in % (it not enter 0):0
# enter your Yellow_fingers rate in % (it not enter 0):2
# enter your Anxiety rate in % (it not enter 0):1
# enter your Peer_Pressure rate in % (it not enter 0):1
# enter your Chronic disease rate in % (it not enter 0):1
# enter your Wheezing rate in % (it not enter 0):2
# enter your Alcohol consuming rate in % (it not enter 0):2
# enter your Fatigue rate in % (it not enter 0):2
# enter your Coughing rate in % (it not enter 0):2
# enter your Shortness of breathe rate in % (it not enter 0):2
# enter your Swallowing difficulty rate in % (it not enter 0):2
# enter your Chest pain rate in % (it not enter 0):2
# enter your Lung_cancer rate in % (it not enter 0):1
# Your Lung cancer is prediction [8.2]%
# have good day......!
